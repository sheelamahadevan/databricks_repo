# %%
print("Welcome")

# %%
# %sql
select current_date
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
for i in range(100):
    if(i%5==0):
        print(i)

# %%
# %sh
ls

# %%
# %sh
pwd
